# %% [markdown]
# Connected to base (Python 3.12.4)

# %%
pd.read_sql("""SELECT 
                m.ANHO_MU, 
                m.COD_SIES,
                m.NIV_GLO,
                m.COD_SIES,
                c.FACULTAD
            FROM TABLA_MU_2016_2026 m
            LEFT JOIN CPP_DR2 c
            ON c.SIES=m.COD_SIES""", con_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File Untitled-1:1
# ----> 1 pd.read_sql("""SELECT
#       2                 m.ANHO_MU,
#       3                 m.COD_SIES,
#       4                 m.NIV_GLO,
#       5                 m.COD_SIES,
#       6                 c.FACULTAD
#       7             FROM TABLA_MU_2016_2026 m
#       8             LEFT JOIN CPP_DR2 c
#       9             ON c.SIES=m.COD_SIES""", con_1)
#
# NameError: name 'pd' is not defined

# %%
import pyodbc
import pandas as pd
import numpy as np
from datetime import date

# %%
pd.read_sql("""SELECT 
                m.ANHO_MU, 
                m.COD_SIES,
                m.NIV_GLO,
                m.COD_SIES,
                c.FACULTAD
            FROM TABLA_MU_2016_2026 m
            LEFT JOIN CPP_DR2 c
            ON c.SIES=m.COD_SIES""", con_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File Untitled-1:9
#       1 pd.read_sql("""SELECT
#       2                 m.ANHO_MU,
#       3                 m.COD_SIES,
#       4                 m.NIV_GLO,
#       5                 m.COD_SIES,
#       6                 c.FACULTAD
#       7             FROM TABLA_MU_2016_2026 m
#       8             LEFT JOIN CPP_DR2 c
# ----> 9             ON c.SIES=m.COD_SIES""", con_1)
#
# NameError: name 'con_1' is not defined

# %%
con_1 = pyodbc.connect(
    f"DRIVER={{ODBC Driver 17 for SQL Server}};"
    f"SERVER=158.170.66.56,{1433};"
    f"DATABASE=PROC01ESTUDIO;"
    f"UID=proceso;"
    f"PWD=Estudio.2024;")

print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
pd.read_sql("""SELECT 
                m.ANHO_MU, 
                m.COD_SIES,
                m.NIV_GLO,
                m.COD_SIES,
                c.FACULTAD
            FROM TABLA_MU_2016_2026 m
            LEFT JOIN CPP_DR2 c
            ON c.SIES=m.COD_SIES""", con_1)
# Out:
# <ipython-input-5-8d61126298e1>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("""SELECT
#         ANHO_MU          COD_SIES   NIV_GLO          COD_SIES  \
# 0          2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 1          2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 2          2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 3          2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 4          2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# ...         ...               ...       ...               ...
# 9810399    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# 9810400    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# 9810401    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# 9810402    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# ...

# %%
pd.read_sql("""SELECT 
                m.ANHO_MU, 
                m.COD_SIES,
                m.NIV_GLO,
                m.COD_SIES,
                c.FACULTAD
            FROM TABLA_MU_2016_2026 m
            LEFT JOIN CPP_DR2 c
            ON CONCAT(c.SIES, '-', c.ANHO) = CONCAT(m.COD_SIES, '-', m.ANHO_MU)""", con_1)
# Out:
# <ipython-input-6-920076528167>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("""SELECT
#        ANHO_MU          COD_SIES   NIV_GLO          COD_SIES  \
# 0         2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 1         2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 2         2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 3         2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# 4         2025    I71S1C1001J2V1  PREGRADO    I71S1C1001J2V1
# ...        ...               ...       ...               ...
# 515809    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# 515810    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# 515811    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# 515812    2016  I71S1CN_P_5JNAV5      None  I71S1CN_P_5JNAV5
# ...

# %% [markdown]
# Connected to base (Python 3.12.4)

# %% [markdown]
# No kernel connected

# %% [markdown]
# Connected to base (Python 3.12.4)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np
from gspread_dataframe import set_with_dataframe

# %%
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('/home/xenomorfo/Descargas/bamboo-sweep-465617-i4-06b9bd6f36a5.json', scope)
client = gspread.authorize(credentials)

# %%
spreadsheet = client.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE')
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# File Untitled-1:1
# ----> 1 spreadsheet = client.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE')
#
# File ~/anaconda3/lib/python3.12/site-packages/gspread/client.py:174, in Client.open_by_key(self, key)
#     172     if ex.response.status_code == HTTPStatus.FORBIDDEN:
#     173         raise PermissionError from ex
# --> 174     raise ex
#     175 return spreadsheet
#
# File ~/anaconda3/lib/python3.12/site-packages/gspread/client.py:168, in Client.open_by_key(self, key)
#     160 """Opens a spreadsheet specified by `key` (a.k.a Spreadsheet ID).
#     161
#     162 :param str key: A key of a spreadsheet as it appears in a URL in a browser.
#    (...)
#     165 >>> gc.open_by_key('0BmgG6nO_6dprdS1MN3d3MkdPa142WFRrdnRRUWl1UFE')
#     166 """
#     167 try:
# ...

# %%
spreadsheet = client.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE')
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# File Untitled-1:1
# ----> 1 spreadsheet = client.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE')
#
# File ~/anaconda3/lib/python3.12/site-packages/gspread/client.py:174, in Client.open_by_key(self, key)
#     172     if ex.response.status_code == HTTPStatus.FORBIDDEN:
#     173         raise PermissionError from ex
# --> 174     raise ex
#     175 return spreadsheet
#
# File ~/anaconda3/lib/python3.12/site-packages/gspread/client.py:168, in Client.open_by_key(self, key)
#     160 """Opens a spreadsheet specified by `key` (a.k.a Spreadsheet ID).
#     161
#     162 :param str key: A key of a spreadsheet as it appears in a URL in a browser.
#    (...)
#     165 >>> gc.open_by_key('0BmgG6nO_6dprdS1MN3d3MkdPa142WFRrdnRRUWl1UFE')
#     166 """
#     167 try:
# ...

# %%
spreadsheet = client.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE-os')

# %%
(
gspread.authorize(credentials)
.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE-os')
worksheet(rev)
.get_all_values())
# Out:
#   Cell In[6], line 2
#     gspread.authorize(credentials)
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
(
gspread.authorize(credentials)
.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE-os')
.worksheet("rev")
.get_all_values())
# Out:
# [['',
#   '',
#   '',
#   'mat',
#   '',
#   '',
#   'mat_1er_anio',
#   '',
#   '',
#   'jce_doc',
#   '',
#   '',
#   'n°_prog_diurnos',
#   '',
#   '',
#   'tit op',
#   '',
#   '',
#   'ret_1',
#   '',
#   ''],
#  ['DEPARTAMENTOS',
#   'Departamentos',
#   'Departamentos',
#   '2023',
#   '2024',
#   '2025',
#   '2023',
#   '2024',
#   '2025',
#   '2023',
#   '2024',
#   '2025',
#   '2023',
#   '2024',
#   '2025',
#   '2023',
#   '2024',
#   '2025',
#   '2023',
#   '2024',
#   '2025'],
#  ['BACHILLERATO EN CIENCIAS Y HUMANIDADES',
#   'Bachillerato En Ciencias Y Humanidades',
#   'Bachillerato En Ciencias Y Humanidades',
#   '298',
#   '234',
#   '273',
#   '185',
#   '127',
#   '161',
#   '0,68',
#   '0,60',
#   '0,69',
#   '1',
#   '1',
#   '1',
#   'N/A',
#   '0,00',
#   '0,00',
#   '73,5%',
#   '0,78',
#   '0,78'],
#  ['DEPARTAMENTO DE ADMINISTRACION',
#   'Departamento De Administracion',
#   'Departamento De Administracion',
#   '1675',
#   '1582',
#   '1559',
#   '373',
# ...

# %%
rev = (
gspread.authorize(credentials)
.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE-os')
.worksheet("rev")
.get_all_values())

# %%
pd.DataFrame(rev[1:], columns=rev[0])
# Out:
#                                             \
# 0                            DEPARTAMENTOS
# 1   BACHILLERATO EN CIENCIAS Y HUMANIDADES
# 2           DEPARTAMENTO DE ADMINISTRACION
# 3                 DEPARTAMENTO DE ECONOMIA
# 4                 DEPARTAMENTO DE BIOLOGIA
# ..                                     ...
# 81                   Escuela de Psicologia
# 82     Departamento de Publicidad e Imagen
# 83                  Facultad de Ingenieria
# 84   Departamento de Ciencias del Ambiente
# 85                                    2024
#
#                                             \
# 0                            Departamentos
# 1   Bachillerato En Ciencias Y Humanidades
# 2           Departamento De Administracion
# 3                 Departamento De Economia
# 4                 Departamento De Biologia
# ..                                     ...
# 81                   Escuela De Psicologia
# 82     Departamento De Publicidad E Imagen
# 83                  Facultad De Ingenieria
# ...

# %%
cidi = (
gspread.authorize(credentials)
.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE-os')
.worksheet("cidi")
.get_all_values())



pd.DataFrame(cidi[1:], columns=cidi[0])
# Out:
#                                                         \
# 0          2023-BACHILLERATO EN CIENCIAS Y HUMANIDADES
# 1                  2023-DEPARTAMENTO DE ADMINISTRACION
# 2                        2023-DEPARTAMENTO DE ECONOMIA
# 3                        2023-DEPARTAMENTO DE BIOLOGIA
# 4    2023-DEPARTAMENTO DE CIENCIA Y TECNOLOGIA DE L...
# ..                                                 ...
# 134
# 135
# 136
# 137
# 138
#
#                                               FACULTAD   AÑO  \
# 0                              VICERRECTORIA ACADEMICA  2023
# 1                                                  FAE  2023
# 2                                                  FAE  2023
# 3                                                 FQYB  2023
# 4                                               FACTEC  2023
# ..                                                 ...   ...
# 134  7) Tasa de retención de los maatrículados en e...
# 135
# 136
# 137
# 138
#
# ...

# %%
cidi = (
gspread.authorize(credentials)
.open_by_key('1r1nsHibT3kCTnSPhiPxOOZU3-pIP5oq5kfLi6pYE-os')
.worksheet("cidi")
.get_all_values())



pd.DataFrame(cidi[1:], columns=cidi[0])
# Out:
#                                                     id  \
# 0          2023-BACHILLERATO EN CIENCIAS Y HUMANIDADES
# 1                  2023-DEPARTAMENTO DE ADMINISTRACION
# 2                        2023-DEPARTAMENTO DE ECONOMIA
# 3                        2023-DEPARTAMENTO DE BIOLOGIA
# 4    2023-DEPARTAMENTO DE CIENCIA Y TECNOLOGIA DE L...
# ..                                                 ...
# 134
# 135
# 136
# 137
# 138
#
#                                               FACULTAD   AÑO  \
# 0                              VICERRECTORIA ACADEMICA  2023
# 1                                                  FAE  2023
# 2                                                  FAE  2023
# 3                                                 FQYB  2023
# 4                                               FACTEC  2023
# ..                                                 ...   ...
# 134  7) Tasa de retención de los maatrículados en e...
# 135
# 136
# 137
# 138
#
# ...
